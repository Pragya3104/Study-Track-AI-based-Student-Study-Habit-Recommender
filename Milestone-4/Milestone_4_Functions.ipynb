# %% [markdown]
# # Milestone 4 Functions Notebook
# This notebook imports database functions for testing.

# %%
import db_functions
print('Functions loaded successfully.')
# Out:
# Functions loaded successfully.
